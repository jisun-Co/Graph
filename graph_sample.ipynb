# %% [markdown]
# #개발 환경
# python version is 3.8.16 (default, Mar  2 2023, 03:18:16) [MSC v.1916 64 bit (AMD64)]
# pandas version is 1.5.3
# numpy version is 1.23.5
# matplotlib version is 3.7.1

# %%
import pandas as pd
import sys
sys.path.append(r'D:\Python code\Graph_coding')
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mat
from matplotlib import font_manager, rc_context
#import preset
# print("python version is", sys.version)
# print("pandas version is", pd.__version__)
# print("numpy version is", np.__version__)
# print("matplotlib version is", mat.__version__)
# Out:
# python version is 3.8.16 (default, Mar  2 2023, 03:18:16) [MSC v.1916 64 bit (AMD64)]
# pandas version is 1.5.3
# numpy version is 1.23.5
# matplotlib version is 3.7.1

# %%
data = pd.read_csv(r'data_1.csv')
data_temp = data[:]
data_temp.drop(['time','ch.4','ch.5'],axis=1,inplace=True)
mean = data_temp.mean(axis=1,skipna=False)
min = data_temp.min(axis=1,skipna=False)
max = data_temp.max(axis=1,skipna=False)
data['averge']=mean
data['min']=min
data['max']=max

x = data['time']
y = data['averge']
y1 = data['min']
y2 = data['max']
y3 = data['ch.4']
y4 = data['ch.5']
    
    
plt.plot(x,y, '-', label = 'Surface Mean Temp', color = 'black')
plt.plot(x,y1, '--', label = 'Surface Min Temp', color = 'red')
plt.plot(x,y2, '--', label = 'Surface Max Temp', color = 'blue')    
plt.plot(x,y3, '-', label = 'Surface Max Temp', color = 'green')  
plt.plot(x,y4, '-', label = 'Surface Max Temp', color = 'red')  
#plt.yticks(100)


font_name = font_manager.FontProperties(fname="C:\Windows\Fonts\Arial.ttf").get_name()
plt.rcParams['font.family'] = font_name
plt.rcParams['font.size'] = 10
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.color'] = 'r'
plt.rcParams['axes.grid'] = 1
plt.rcParams['axes.xmargin'] = 0
plt.rcParams['axes.ymargin'] = 0
plt.rcParams['mathtext.fontset'] = "dejavuserif"
plt.rcParams['figure.dpi'] = 500
plt.rcParams['savefig.dpi'] = 500

plt.legend(loc = 'best')
plt.legend(loc = (1.02,0.02))
plt.xlabel('Time[sec]', fontsize=20)
plt.ylabel('Temp.(°C)', fontsize=20)
# plt.ylim(0, 250)
# plt.xlim(0, 50)
plt.yticks(np.arange(0,275,25))
plt.xticks(np.arange(0,55,5)) 

plt.show()
# Out:
# C:\Users\KITECH\AppData\Local\Temp\ipykernel_31992\485615868.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_temp.drop(['time','ch.4','ch.5'],axis=1,inplace=True)
